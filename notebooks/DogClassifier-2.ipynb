# %% [markdown]
# # Stanford Dogs Dataset

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.metrics import error_rate
import numpy as np

# %%
np.random.seed(23)

# %%
path = Path("/home/jupyter/data")
data = ImageDataBunch.from_folder(path, 
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['affenpinscher',
#  'afghan_hound',
#  'african_hunting_dog',
#  'airedale',
#  'american_staffordshire_terrier',
#  'appenzeller',
#  'australian_terrier',
#  'basenji',
#  'basset',
#  'beagle',
#  'bedlington_terrier',
#  'bernese_mountain_dog',
#  'black',
#  'blenheim_spaniel',
#  'bloodhound',
#  'bluetick',
#  'border_collie',
#  'border_terrier',
#  'borzoi',
#  'boston_bull',
#  'bouvier_des_flandres',
#  'boxer',
#  'brabancon_griffon',
#  'briard',
#  'brittany_spaniel',
#  'bull_mastiff',
#  'cairn',
#  'cardigan',
#  'chesapeake_bay_retriever',
#  'chihuahua',
#  'chow',
#  'clumber',
#  'cocker_spaniel',
#  'collie',
#  'curly',
#  'dandie_dinmont',
#  'dhole',
#  'dingo',
#  'doberman',
#  'english_foxhound',
#  'english_setter',
#  'english_springer',
#  'entlebucher',
#  'eskimo_dog',
#  'flat',
#  'french_bulldog',
#  'german_shepherd',
#  'german_short',
#  'giant_schnauzer',
#  'golden_retriever',
#  'gordon_setter',
#  'great_dane',
#  'great_pyrenees',
#  'greater_swiss_mountain_dog',
#  'groenendael',
#  'ibizan_hound',
#  'irish_setter',
#  'irish_terrier',
#  'irish_water_spaniel',
#  'irish_wolfhound',
#  'italian_greyhound',
#  'japanese_spaniel',
#  'keeshond',
#  'kelpie',
#  'kerry_blue_terrier',
#  'komondor',
#  'kuvasz',
#  'labrador_retriever',
#  'lakeland_terrier',
#  'leonberg',
#  'lhasa',
#  'malamute',
#  'malinois',
#  'maltese_dog',
#  'mexican_hairless',
#  'miniature_pinscher',
#  'miniature_poodle',
#  'miniature_schnauzer',
#  'newfoundland',
#  'norfolk_terrier',
#  'norwegian_elkhound',
#  'norwich_terrier',
#  'old_english_sheepdog',
#  'otterhound',
#  'papillon',
#  'pekinese',
#  'pembroke',
#  'pomeranian',
#  'pug',
#  'redbone',
#  'rhodesian_ridgeback',
#  'rottweiler',
#  'saint_bernard',
#  'saluki',
#  'samoyed',
#  'schipperke',
#  'scotch_terrier',
#  'scottish_deerhound',
#  'sealyham_terrier',
#  'shetland_sheepdog',
#  'shih',
#  'siberian_husky',
#  'silky_terrier',
#  'soft',
#  'staffordshire_bullterrier',
#  'standard_poodle',
#  'standard_schnauzer',
#  'sussex_spaniel',
#  'tibetan_mastiff',
#  'tibetan_terrier',
#  'toy_poodle',
#  'toy_terrier',
#  'vizsla',
#  'walker_hound',
#  'weimaraner',
#  'welsh_springer_spaniel',
#  'west_highland_white_terrier',
#  'whippet',
#  'wire',
#  'yorkshire_terrier']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
len(data.train_ds), len(data.valid_ds),
# Out:
# (8760, 2760)

# %%
learn = cnn_learner(data, models.resnet50, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /home/jupyter/.cache/torch/checkpoints/resnet50-19c8e357.pth
# 100%|██████████| 102502400/102502400 [00:00<00:00, 103859407.81it/s]

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.701673</td>
#       <td>0.603970</td>
#       <td>0.174275</td>
#       <td>01:36</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.826912</td>
#       <td>0.513976</td>
#       <td>0.163768</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.550950</td>
#       <td>0.420157</td>
#       <td>0.127536</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.418328</td>
#       <td>0.397217</td>
#       <td>0.120290</td>
#       <td>01:28</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.583340</td>
#       <td>0.493699</td>
#       <td>0.151449</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.427797</td>
#       <td>0.407407</td>
#       <td>0.129348</td>
#       <td>01:28</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stanford-dogs-2-stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(4, max_lr=slice(1e-06, 1e-05))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.358125</td>
#       <td>0.401988</td>
#       <td>0.123188</td>
#       <td>01:54</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.351282</td>
#       <td>0.395122</td>
#       <td>0.123913</td>
#       <td>01:55</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.325938</td>
#       <td>0.394662</td>
#       <td>0.122464</td>
#       <td>01:54</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.320422</td>
#       <td>0.396483</td>
#       <td>0.122101</td>
#       <td>01:55</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stanford-dogs-2-stage-2')

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
learn.export('stanford-dogs-2-stage-2')
